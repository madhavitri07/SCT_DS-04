# %%
pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2026.1.4)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.5.1)

# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from opendatasets) (4.67.1)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (from opendatasets) (1.7.4.5)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from opendatasets) (8.3.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2026.1.4)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle->opendatasets) (0.5.1)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import opendatasets as od
import pandas

od.download(
	"https://www.kaggle.com/sobhanmoosavi/us-accidents")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Dataset URL: https://www.kaggle.com/datasets/sobhanmoosavi/us-accidents
# Downloading us-accidents.zip to ./us-accidents
# 100%|██████████| 653M/653M [00:10<00:00, 66.6MB/s]

# %%
import numpy as np
import pandas as pd

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as mn
import plotly.graph_objects as go

# %%
from matplotlib.ticker import FuncFormatter
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches
import matplotlib.patheffects as PathEffects
# %matplotlib inline

import calendar
import plotly as pt
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from pylab import *

import plotly.graph_objects as go
from nltk.corpus import stopwords

import geopandas as gpd
from geopy.geocoders import Nominatim

import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
data_filepath = "/content/us-accidents/US_Accidents_March23.csv"

# %%
import pandas as pd

df = pd.read_csv(
    "/content/us-accidents/US_Accidents_March23.csv",
    nrows=100000   # ONLY 1 lakh rows
)

df.head()
# Out:
#     ID   Source  Severity           Start_Time             End_Time  \
# 0  A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1  A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2  A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3  A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4  A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False          Night
# 1   False  False           False          False        False          Night
# 2   False  False           False           True        False          Night
# 3   False  False           False          False        False          Night
# 4   False  False           False           True        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day
#
# [5 rows x 46 columns]

# %%
# Checking the columns in the data
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
print("Number of columns: ",len(df.columns))
print("Number of rows: ",len(df))
# Out:
# Number of columns:  46
# Number of rows:  100000

# %% [markdown]
# Gathering information about the dataset
#
# Missing values
# Null values
# Type of data in the file

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     100000 non-null  object
#  1   Source                 100000 non-null  object
#  2   Severity               100000 non-null  int64
#  3   Start_Time             100000 non-null  object
#  4   End_Time               100000 non-null  object
#  5   Start_Lat              100000 non-null  float64
#  6   Start_Lng              100000 non-null  float64
#  7   End_Lat                0 non-null       float64
#  8   End_Lng                0 non-null       float64
#  9   Distance(mi)           100000 non-null  float64
#  10  Description            100000 non-null  object
#  11  Street                 100000 non-null  object
#  12  City                   99999 non-null   object
#  13  County                 100000 non-null  object
#  14  State                  100000 non-null  object
#  15  Zipcode                99993 non-null   object
#  16  Country                100000 non-null  object
#  17  Timezone               99993 non-null   object
#  18  Airport_Code           99993 non-null   object
#  19  Weather_Timestamp      98946 non-null   object
#  20  Temperature(F)         98409 non-null   float64
#  21  Wind_Chill(F)          4322 non-null    float64
#  22  Humidity(%)            98144 non-null   float64
#  23  Pressure(in)           98708 non-null   float64
#  24  Visibility(mi)         98154 non-null   float64
#  25  Wind_Direction         98936 non-null   object
#  26  Wind_Speed(mph)        76180 non-null   float64
#  27  Precipitation(in)      7368 non-null    float64
#  28  Weather_Condition      98396 non-null   object
#  29  Amenity                100000 non-null  bool
#  30  Bump                   100000 non-null  bool
#  31  Crossing               100000 non-null  bool
#  32  Give_Way               100000 non-null  bool
#  33  Junction               100000 non-null  bool
#  34  No_Exit                100000 non-null  bool
#  35  Railway                100000 non-null  bool
#  36  Roundabout             100000 non-null  bool
#  37  Station                100000 non-null  bool
#  38  Stop                   100000 non-null  bool
#  39  Traffic_Calming        100000 non-null  bool
#  40  Traffic_Signal         100000 non-null  bool
#  41  Turning_Loop           100000 non-null  bool
#  42  Sunrise_Sunset         99999 non-null   object
#  43  Civil_Twilight         99999 non-null   object
#  44  Nautical_Twilight      99999 non-null   object
#  45  Astronomical_Twilight  99999 non-null   object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 26.4+ MB

# %%
df.describe()
# Out:
#             Severity      Start_Lat      Start_Lng  End_Lat  End_Lng  \
# count  100000.000000  100000.000000  100000.000000      0.0      0.0
# mean        2.448120      35.630369    -119.322756      NaN      NaN
# std         0.499931       2.101259       3.663525      NaN      NaN
# min         1.000000      32.542587    -123.813927      NaN      NaN
# 25%         2.000000      33.957775    -121.828468      NaN      NaN
# 50%         2.000000      34.168579    -118.384232      NaN      NaN
# 75%         3.000000      37.776682    -117.916023      NaN      NaN
# max         4.000000      41.428753     -81.550728      NaN      NaN
#
#         Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  100000.000000    98409.000000    4322.000000  98144.000000
# mean        0.011345       66.641262      48.845812     59.794170
# std         0.262244       12.703846      19.898270     23.184442
# min         0.000000        3.200000      -8.400000      4.000000
# 25%         0.000000       57.900000      37.100000     43.000000
# 50%         0.000000       66.000000      42.500000     62.000000
# 75%         0.010000       75.000000      63.000000     78.000000
# max        51.130000      114.100000     107.000000    100.000000
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  98708.000000    98154.000000     76180.000000        7368.000000
# mean      29.961021        9.338639         8.044165           0.025786
# std        0.275672        1.885828         4.298926           0.051695
# min        2.980000        0.100000         0.000000           0.000000
# 25%       29.890000       10.000000         4.600000           0.000000
# 50%       29.970000       10.000000         6.900000           0.000000
# 75%       30.060000       10.000000        10.400000           0.030000
# max       33.040000       80.000000       241.700000           0.550000

# %% [markdown]
# How many columns are numerical data?*italicized text*

# %%
len(df.select_dtypes(['int64', 'float64']).columns)
# Out:
# 13

# %% [markdown]
# Missing or incorrect values?

# %%
df.isnull().sum()
# Out:
# ID                            0
# Source                        0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# End_Lat                  100000
# End_Lng                  100000
# Distance(mi)                  0
# Description                   0
# Street                        0
# City                          1
# County                        0
# State                         0
# Zipcode                       7
# Country                       0
# Timezone                      7
# Airport_Code                  7
# Weather_Timestamp          1054
# Temperature(F)             1591
# Wind_Chill(F)             95678
# Humidity(%)                1856
# Pressure(in)               1292
# Visibility(mi)             1846
# Wind_Direction             1064
# Wind_Speed(mph)           23820
# Precipitation(in)         92632
# Weather_Condition          1604
# Amenity                       0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# Junction                      0
# No_Exit                       0
# Railway                       0
# Roundabout                    0
# Station                       0
# Stop                          0
# Traffic_Calming               0
# Traffic_Signal                0
# Turning_Loop                  0
# Sunrise_Sunset                1
# Civil_Twilight                1
# Nautical_Twilight             1
# Astronomical_Twilight         1
# dtype: int64

# %%
df.isna().sum()
# Out:
# ID                            0
# Source                        0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# End_Lat                  100000
# End_Lng                  100000
# Distance(mi)                  0
# Description                   0
# Street                        0
# City                          1
# County                        0
# State                         0
# Zipcode                       7
# Country                       0
# Timezone                      7
# Airport_Code                  7
# Weather_Timestamp          1054
# Temperature(F)             1591
# Wind_Chill(F)             95678
# Humidity(%)                1856
# Pressure(in)               1292
# Visibility(mi)             1846
# Wind_Direction             1064
# Wind_Speed(mph)           23820
# Precipitation(in)         92632
# Weather_Condition          1604
# Amenity                       0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# Junction                      0
# No_Exit                       0
# Railway                       0
# Roundabout                    0
# Station                       0
# Stop                          0
# Traffic_Calming               0
# Traffic_Signal                0
# Turning_Loop                  0
# Sunrise_Sunset                1
# Civil_Twilight                1
# Nautical_Twilight             1
# Astronomical_Twilight         1
# dtype: int64

# %% [markdown]
# Finding the percantage of missing data per columns?

# %%
df.isna().sum().sort_values(ascending=False) * 100. / len(df)
# Out:
# End_Lng                  100.000
# End_Lat                  100.000
# Wind_Chill(F)             95.678
# Precipitation(in)         92.632
# Wind_Speed(mph)           23.820
# Humidity(%)                1.856
# Visibility(mi)             1.846
# Weather_Condition          1.604
# Temperature(F)             1.591
# Pressure(in)               1.292
# Wind_Direction             1.064
# Weather_Timestamp          1.054
# Timezone                   0.007
# Zipcode                    0.007
# Airport_Code               0.007
# Nautical_Twilight          0.001
# Civil_Twilight             0.001
# City                       0.001
# Astronomical_Twilight      0.001
# Sunrise_Sunset             0.001
# Description                0.000
# Street                     0.000
# Source                     0.000
# ID                         0.000
# Severity                   0.000
# Distance(mi)               0.000
# Start_Lng                  0.000
# Start_Time                 0.000
# End_Time                   0.000
# Start_Lat                  0.000
# County                     0.000
# Amenity                    0.000
# Country                    0.000
# State                      0.000
# Bump                       0.000
# Crossing                   0.000
# Give_Way                   0.000
# Junction                   0.000
# Station                    0.000
# Roundabout                 0.000
# Railway                    0.000
# No_Exit                    0.000
# Turning_Loop               0.000
# Traffic_Signal             0.000
# Traffic_Calming            0.000
# Stop                       0.000
# dtype: float64

# %% [markdown]
# Plotting the missing percentages

# %%
# Plotting a Pandas.Series data
missing_data = df.isna().sum().sort_values(ascending=False) * 100. / len(df)

# %%
type(missing_data) # we can directly plot the Pandas.Series using plot()
# Out:
# pandas.core.series.Series

# %%
missing_data.plot(kind='bar')
# Out:
# <Axes: >

# %%
missing_data[missing_data!=0].plot(kind='barh')
# Out:
# <Axes: >

# %%
# Printing all the columns
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.City.unique()
# Out:
# array(['Dayton', 'Reynoldsburg', 'Williamsburg', 'Westerville',
#        'Columbus', 'Miamisburg', 'Johnstown', 'Dublin',
#        'Canal Winchester', 'Lebanon', 'Sabina', 'Goshen', 'Waynesville',
#        'Springboro', 'Carroll', 'Oregonia', 'Independence',
#        'Maple Heights', 'Grove City', 'Findlay', 'Fairborn', 'Piqua',
#        'New Richmond', 'Batavia', 'Galena', 'Barberton', 'Akron',
#        'Mansfield', 'Cleveland', 'Bethel', 'Pataskala', 'Seville',
#        'Bellville', 'Troy', 'Wilmington', 'North Olmsted', 'Groveport',
#        'Orient', 'Tiro', 'Strongsville', 'Beavercreek', 'Circleville',
#        'Peebles', 'Hurricane', 'Xenia', 'Elyria', 'Pickerington',
#        'Burbank', 'Zanesville', 'North Baltimore', 'Mount Sterling',
#        'Tipp City', 'Moraine', 'Hilliard', 'Bowling Green', 'Maineville',
#        'Vermilion', 'Milford', 'Brookpark', 'Fraziers Bottom',
#        'Cambridge', 'Delaware', 'Moscow', 'Oberlin', 'Sardinia',
#        'Lewis Center', 'Urbancrest', 'Brecksville', 'Frankfort',
#        'Blanchester', 'Casstown', 'Lima', 'Amelia', 'Newark',
#        'Springfield', 'Vandalia', 'Galloway', 'Bloomingburg',
#        'Gallipolis', 'Lockbourne', 'Milan', 'Mason', 'Millersport',
#        'New Carlisle', 'Sunbury', 'Owensville', 'London', 'Vallejo',
#        'Hayward', 'Walnut Creek', 'Cupertino', 'San Jose', 'Pleasanton',
#        'San Francisco', 'Orinda', 'Livermore', 'Cotati', 'Concord',
#        'Sunnyvale', 'Sacramento', 'Oakland', 'Alviso', 'Morgan Hill',
#        'Petaluma', 'Martinez', 'Millbrae', 'North Highlands', 'Windsor',
#        'Alamo', 'San Martin', 'Healdsburg', 'Brisbane', 'Palo Alto',
#        'Milpitas', 'Davis', 'Elk Grove', 'Half Moon Bay', 'Menlo Park',
#        'Tracy', 'Carmichael', 'Granite Bay', 'Union City',
#        'Pleasant Hill', 'San Mateo', 'Rancho Cordova', 'Nevada City',
#        'Vacaville', 'Roseville', 'Isleton', 'Lincoln', 'El Dorado',
#        'Corte Madera', 'San Leandro', 'Danville', 'Los Gatos',
#        'Castro Valley', 'Stockton', 'Willits', 'Santa Rosa', 'Los Altos',
#        'Richmond', 'Dixon', 'Nice', 'Antioch', 'Angwin', 'Novato',
#        'Burlingame', 'Sunol', 'Placerville', 'Fairfield', 'Scotts Valley',
#        'Linden', 'Santa Clara', 'San Pablo', 'Pinole', 'Redwood City',
#        'Salinas', 'Soquel', 'Monterey', 'Fremont', 'Hercules', 'Seaside',
#        'Saratoga', 'American Canyon', 'Wilton', 'Pittsburg',
#        'Grass Valley', 'Santa Cruz', 'Lodi', 'Sonoma', 'Auburn',
#        'Orangevale', 'Emeryville', 'South San Francisco', 'Lathrop',
#        'Cameron Park', 'San Bruno', 'Modesto', 'Berkeley', 'Gilroy',
#        'Escalon', 'Byron', 'Penryn', 'Citrus Heights', 'El Dorado Hills',
#        'El Cerrito', 'Suisun City', 'Fair Oaks', 'Napa', 'Colfax',
#        'Rocklin', 'Mather', 'Mill Valley', 'San Carlos', 'Aptos',
#        'San Ramon', 'Woodland', 'Loomis', 'Folsom', 'Walnut Grove',
#        'Rodeo', 'San Lorenzo', 'Sausalito', 'Portola Valley',
#        'Pope Valley', 'Manteca', 'Daly City', 'Mokelumne Hill',
#        'Occidental', 'Newcastle', 'Guerneville', 'Calistoga', 'Galt',
#        'Crockett', 'Glen Ellen', 'Rohnert Park', 'Jackson', 'Ripon',
#        'Lafayette', 'Fulton', 'Sebastopol', 'San Quentin', 'Forestville',
#        'Hollister', 'West Sacramento', 'Angels Camp', 'Acampo',
#        'Valley Springs', 'Delhi', 'Shingle Springs', 'Ione', 'Yountville',
#        'French Camp', 'Meadow Vista', 'Penn Valley', 'San Rafael',
#        'Herald', 'Castroville', 'Camino', 'The Sea Ranch', 'Ben Lomond',
#        'Moss Landing', 'Aromas', 'Elverta', 'Soledad', 'Yuba City',
#        'Dos Palos', 'Salida', 'Lucerne', 'Antelope', 'Rio Linda',
#        'Benicia', 'Lower Lake', 'Winters', 'Oakdale', 'Turlock',
#        'Belmont', 'Boulder Creek', 'Carmel', 'Mountain View',
#        'Royal Oaks', 'Foresthill', 'Mendota', 'Keyes', 'Firebaugh',
#        'Monte Rio', 'Campbell', 'Larkspur', 'Nicasio', 'Bodega Bay',
#        'Brentwood', 'San Gregorio', 'El Sobrante', 'Travis Afb', 'Newman',
#        'Kelseyville', 'Carmel Valley', 'Meridian', 'Capitola', 'Lakeport',
#        'Rumsey', 'Middletown', 'Georgetown', 'Biggs', 'Waterford',
#        'Nicolaus', 'Gonzales', 'Greenbrae', 'Patterson', 'Rio Vista',
#        'Dunnigan', 'Copperopolis', 'Alta', 'Willows', 'Marysville',
#        'Winton', 'Hilmar', 'Ukiah', 'Penngrove', 'Clarksburg', 'Esparto',
#        'McClellan', 'Garden Valley', 'Oroville', 'Pacifica', 'Los Banos',
#        'La Grange', 'Arbuckle', 'San Juan Bautista', 'Geyserville',
#        'Jenner', 'Stanford', 'Oregon House', 'San Andreas', 'Dobbins',
#        'Brooks', 'Sloughhouse', 'Pollock Pines', 'Hopland',
#        'Discovery Bay', 'Ceres', 'Bay Point', 'Rescue', 'Mcclellan',
#        'Little River', 'Watsonville', 'Emerald Hills', 'Diamond Springs',
#        'Felton', 'Cool', 'Pine Grove', 'Upper Lake', 'Clearlake Oaks',
#        'Woodside', 'Atwater', 'Sutter Creek', 'Lockeford', 'Coyote',
#        'Pescadero', 'La Honda', 'Pioneer', 'Lotus', 'Gustine', 'Ballico',
#        'Cloverdale', 'Fairfax', 'Plymouth', 'Port Costa', 'Smartsville',
#        'Saint Helena', 'Mount Hamilton', 'North San Juan', 'Courtland',
#        'Monte Sereno', 'Applegate', 'Freedom', 'Mountain Ranch', 'Merced',
#        'Clearlake', 'Graton', 'Pacheco', 'Maxwell', 'Kentfield',
#        'Stevinson', 'Somerset', 'Capay', 'Hughson', 'Yorkville',
#        'Clayton', 'Crows Landing', 'Belvedere Tiburon', 'Farmington',
#        'Rough and Ready', 'Zamora', 'Gualala', 'Marina', 'Emigrant Gap',
#        'Rough And Ready', 'Point Reyes Station', 'Southeast Marin',
#        'Soda Springs', 'Moss Beach', 'Vernalis', 'Redwood Valley',
#        'Pebble Beach', 'Williams', 'Dutch Flat', 'Paicines', 'Oakley',
#        'Browns Valley', 'Sutter', 'Gold River', 'Downieville',
#        'Fort Bragg', 'Birds Landing', 'Fiddletown', 'Annapolis',
#        'Rancho Murieta', 'Big Sur', 'Muir Beach', 'Norden', 'Sierra City',
#        'Livingston', 'Jamestown', 'Gridley', 'Pleasant Grove',
#        'Davenport', 'Bodega', 'Sheridan', 'Alameda', 'Gold Run',
#        'Olivehurst', 'Denair', 'Colusa', 'Marshall', 'Valley Ford',
#        'Volcano', 'Kenwood', 'Potter Valley', 'Comptche', 'Cazadero',
#        'Camptonville', 'Wheatland', 'Challenge', 'Pilot Hill', 'Chualar',
#        'Grizzly Flats', 'Stonyford', 'Mendocino', 'Princeton',
#        'Woodbridge', 'Butte City', 'Bolinas', 'Madison', 'Tomales',
#        'Glenhaven', 'Palermo', 'Woodacre', 'Montara', 'Inverness',
#        'Greenwood', 'Glenn', 'Albion', 'Hickman', 'Atherton', 'Albany',
#        'Dillon Beach', 'East Palo Alto', 'Knights Landing', 'West Point',
#        'Cobb', 'El Macero', 'Guinda', 'West Contra Costa', 'Hillsborough',
#        'San Anselmo', 'Diablo', 'Foster City', 'Berry Creek',
#        'Santa Barbara', 'Ventura', 'Simi Valley', 'Sylmar',
#        'North Hollywood', 'Los Angeles', 'La Canada Flintridge',
#        'South El Monte', 'La Puente', 'Orange', 'Santa Ana', 'Pomona',
#        'Riverside', 'Vista', 'Temecula', 'Running Springs', 'Newhall',
#        'Inglewood', 'Downey', 'San Diego', 'Escondido', 'Mentone',
#        'Ontario', 'Fontana', 'Colton', 'Redlands', 'Moreno Valley',
#        'Spring Valley', 'Sun Valley', 'Cerritos', 'Anaheim', 'Tustin',
#        'Highland', 'Santee', 'Buena Park', 'Sherman Oaks', 'Torrance',
#        'Long Beach', 'Montebello', 'Norwalk', 'Pacoima', 'Pasadena',
#        'La Jolla', 'Oxnard', 'Chino', 'Irvine', 'Diamond Bar',
#        'Hacienda Heights', 'El Monte', 'Hemet', 'Calabasas', 'Glendale',
#        'Compton', 'Lynwood', 'Van Nuys', 'Mira Loma', 'Encinitas', 'Pala',
#        'Valencia', 'Corona', 'Carlsbad', 'Commerce', 'Carson',
#        'Valley Village', 'Gardena', 'Whittier', 'Oceanside', 'Perris',
#        'Hesperia', 'Lawndale', 'Fullerton', 'Lake Elsinore',
#        'Santa Fe Springs', 'Canyon Country', 'El Cajon',
#        'Stevenson Ranch', 'Valley Center', 'Culver City', 'San Pedro',
#        'San Bernardino', 'National City', 'Camarillo', 'San Ysidro',
#        'Covina', 'Bloomington', 'Baldwin Park', 'Rialto', 'Alhambra',
#        'Rosemead', 'Brea', 'Porter Ranch', 'Westminster', 'Acton',
#        'Newbury Park', 'Walnut', 'Mission Viejo', 'Altadena',
#        'Forest Falls', 'Rowland Heights', 'Arcadia', 'Menifee',
#        'Chula Vista', 'Landers', 'Moorpark', 'Santa Monica', 'Murrieta',
#        'La Crescenta', 'Encino', 'Topanga', 'March Air Reserve Base',
#        'Harbor City', 'Upland', 'Yorba Linda', 'Solana Beach', 'Alpine',
#        'Montclair', 'Santa Clarita', 'Santa Ysabel', 'Seal Beach',
#        'La Mesa', 'Big Bear City', 'Westlake Village', 'Tarzana',
#        'South Pasadena', 'Grand Terrace', 'Huntington Beach',
#        'Mission Hills', 'San Fernando', 'Hawthorne', 'Bellflower',
#        'Lake Arrowhead', 'Ramona', 'Studio City', 'Beaumont',
#        'Garden Grove', 'Rancho Cucamonga', 'Julian', 'Glendora',
#        'San Gabriel', 'Paramount', 'City Of Industry', 'San Marcos',
#        'Azusa', 'San Dimas', 'South Gate', 'Huntington Park', 'Oak Park',
#        'Marina Del Rey', 'North Hills', 'Cardiff By the Sea',
#        'Woodland Hills', 'Monterey Park', 'Pacific Palisades',
#        'Fallbrook', 'Calimesa', 'Victorville', 'Placentia', 'Bonsall',
#        'San Clemente', 'Fountain Valley', 'Granada Hills', 'West Covina',
#        'Del Mar', 'Thousand Palms', 'Banning', 'Pico Rivera', 'Monrovia',
#        'Costa Mesa', 'San Juan Capistrano', 'San Jacinto', 'Homeland',
#        'La Mirada', 'Bell Gardens', 'Norco', 'Artesia', 'Littlerock',
#        'Chatsworth', 'Laguna Hills', 'Agoura Hills', 'Pauma Valley',
#        'Desert Hot Springs', 'Indio', 'Duarte', 'Stanton', 'Ojai',
#        'Winchester', 'Castaic', 'Silverado', 'Rancho Santa Fe',
#        'Lakeside', 'Coronado', 'Potrero', 'Ladera Ranch', 'Fillmore',
#        'Marina del Rey', 'Palm Springs', 'Foothill Ranch', 'Descanso',
#        'Pine Valley', 'Cabazon', 'North Palm Springs', 'Camp Pendleton',
#        'Toluca Lake', 'Palmdale', 'Loma Linda', 'Carpinteria',
#        'Cathedral City', 'La Verne', 'Valyermo', 'Aguanga', 'Bonita',
#        'Newport Beach', 'Wildomar', 'Lemon Grove', 'Malibu',
#        'Lucerne Valley', 'Phelan', 'Laguna Niguel', 'Nuevo',
#        'Trabuco Canyon', 'Palm Desert', 'View Park', 'Lakewood',
#        'Boulevard', 'Mountain Center', 'Goleta', 'Idyllwild',
#        'Twin Peaks', 'Santa Paula', 'Rimforest', 'La Palma', 'Winnetka',
#        'Vernon', 'La Habra', 'Signal Hill', 'Claremont', 'Sun City',
#        'Montrose', 'Wrightwood', 'Sunland', 'Yucaipa', 'Chino Hills',
#        'Jamul', 'El Segundo', 'Crestline', 'Rolling Hills Estates',
#        'Tujunga', 'Thousand Oaks', 'Pinon Hills', 'Llano', 'Campo',
#        'Capistrano Beach', 'Anza', 'Rancho Dominguez', 'Canoga Park',
#        'Los Alamitos', 'Oak Hills', 'Venice', 'Lake Forest', 'Cedar Glen',
#        'Laguna Beach', 'Aliso Viejo', 'Santa Rosa Valley', 'Angelus Oaks',
#        'Joshua Tree', 'Somis', 'Midway City', 'San Marino',
#        'Playa del Rey', 'Temple City', 'Ranchita', 'Sugarloaf', 'Maywood',
#        'La Habra Heights', 'Corona del Mar', 'Oak View', 'Apple Valley',
#        'Redondo Beach', 'Hawaiian Gardens', 'Yucca Valley', 'Whitewater',
#        'Blue Jay', 'Skyforest', 'Dulzura', 'Irwindale',
#        'Palos Verdes Peninsula', 'Morongo Valley', 'Windsor Hills',
#        'Point Mugu Nawc', 'Universal City', 'Poway', 'Bell',
#        'Bermuda Dunes', 'West Hollywood', 'Lompoc', 'Borrego Springs',
#        'Warner Springs', 'Mt Baldy', 'Cedarpines Park', 'Tecate',
#        'Newport Coast', 'Northridge', 'Cherry Valley',
#        'Rancho Santa Margarita', 'Rancho Mirage', 'Pearblossom',
#        'Big Bear Lake', 'Panorama City', 'Summerland', 'Playa Del Rey',
#        'Bell Canyon', 'Arleta', 'Cypress', 'Dana Point', 'Beverly Hills',
#        'Rancho Palos Verdes', 'Port Hueneme', 'Reseda', 'La Quinta',
#        'Adelanto', 'Piru', 'Hidden Hills', 'Lytle Creek', 'West Hills',
#        nan, 'Sunset Beach', 'Imperial Beach'], dtype=object)

# %%
cities = df.City.unique()
len(cities)
# Out:
# 786

# %% [markdown]
# Getting the number of accidents in each city over all years (2016-2020)

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident[:20]
# Out:
# City
# Los Angeles       9792
# Sacramento        5223
# San Diego         3275
# San Jose          3026
# Oakland           1802
# Long Beach        1343
# San Francisco     1287
# Riverside         1261
# Corona            1095
# Whittier          1019
# San Bernardino     952
# Anaheim            952
# Hayward            934
# Stockton           886
# Fremont            770
# Tracy              753
# Ontario            749
# Santa Rosa         745
# Baldwin Park       744
# Livermore          685
# Name: count, dtype: int64

# %%
'Dayton' in cities
# Out:
# True

# %%
cities_by_accident["Dayton"]
# Out:
# np.int64(321)

# %%
cities_by_accident[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %% [markdown]
# Plotting all the citis by number of accidents accidents

# %%
sns.distplot(cities_by_accident)
# Out:
# <Axes: xlabel='count', ylabel='Density'>

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ID                     100000 non-null  object
#  1   Source                 100000 non-null  object
#  2   Severity               100000 non-null  int64
#  3   Start_Time             100000 non-null  object
#  4   End_Time               100000 non-null  object
#  5   Start_Lat              100000 non-null  float64
#  6   Start_Lng              100000 non-null  float64
#  7   End_Lat                0 non-null       float64
#  8   End_Lng                0 non-null       float64
#  9   Distance(mi)           100000 non-null  float64
#  10  Description            100000 non-null  object
#  11  Street                 100000 non-null  object
#  12  City                   99999 non-null   object
#  13  County                 100000 non-null  object
#  14  State                  100000 non-null  object
#  15  Zipcode                99993 non-null   object
#  16  Country                100000 non-null  object
#  17  Timezone               99993 non-null   object
#  18  Airport_Code           99993 non-null   object
#  19  Weather_Timestamp      98946 non-null   object
#  20  Temperature(F)         98409 non-null   float64
#  21  Wind_Chill(F)          4322 non-null    float64
#  22  Humidity(%)            98144 non-null   float64
#  23  Pressure(in)           98708 non-null   float64
#  24  Visibility(mi)         98154 non-null   float64
#  25  Wind_Direction         98936 non-null   object
#  26  Wind_Speed(mph)        76180 non-null   float64
#  27  Precipitation(in)      7368 non-null    float64
#  28  Weather_Condition      98396 non-null   object
#  29  Amenity                100000 non-null  bool
#  30  Bump                   100000 non-null  bool
#  31  Crossing               100000 non-null  bool
#  32  Give_Way               100000 non-null  bool
#  33  Junction               100000 non-null  bool
#  34  No_Exit                100000 non-null  bool
#  35  Railway                100000 non-null  bool
#  36  Roundabout             100000 non-null  bool
#  37  Station                100000 non-null  bool
#  38  Stop                   100000 non-null  bool
#  39  Traffic_Calming        100000 non-null  bool
#  40  Traffic_Signal         100000 non-null  bool
#  41  Turning_Loop           100000 non-null  bool
#  42  Sunrise_Sunset         99999 non-null   object
#  43  Civil_Twilight         99999 non-null   object
#  44  Nautical_Twilight      99999 non-null   object
#  45  Astronomical_Twilight  99999 non-null   object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 26.4+ MB
#             Severity      Start_Lat      Start_Lng  End_Lat  End_Lng  \
# count  100000.000000  100000.000000  100000.000000      0.0      0.0
# mean        2.448120      35.630369    -119.322756      NaN      NaN
# std         0.499931       2.101259       3.663525      NaN      NaN
# min         1.000000      32.542587    -123.813927      NaN      NaN
# 25%         2.000000      33.957775    -121.828468      NaN      NaN
# 50%         2.000000      34.168579    -118.384232      NaN      NaN
# 75%         3.000000      37.776682    -117.916023      NaN      NaN
# max         4.000000      41.428753     -81.550728      NaN      NaN
#
#         Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  100000.000000    98409.000000    4322.000000  98144.000000
# mean        0.011345       66.641262      48.845812     59.794170
# std         0.262244       12.703846      19.898270     23.184442
# min         0.000000        3.200000      -8.400000      4.000000
# 25%         0.000000       57.900000      37.100000     43.000000
# 50%         0.000000       66.000000      42.500000     62.000000
# 75%         0.010000       75.000000      63.000000     78.000000
# max        51.130000      114.100000     107.000000    100.000000
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  98708.000000    98154.000000     76180.000000        7368.000000
# mean      29.961021        9.338639         8.044165           0.025786
# std        0.275672        1.885828         4.298926           0.051695
# min        2.980000        0.100000         0.000000           0.000000
# 25%       29.890000       10.000000         4.600000           0.000000
# 50%       29.970000       10.000000         6.900000           0.000000
# 75%       30.060000       10.000000        10.400000           0.030000
# max       33.040000       80.000000       241.700000           0.550000

# %%
df.isnull().sum()
# Out:
# ID                            0
# Source                        0
# Severity                      0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# Start_Lng                     0
# End_Lat                  100000
# End_Lng                  100000
# Distance(mi)                  0
# Description                   0
# Street                        0
# City                          1
# County                        0
# State                         0
# Zipcode                       7
# Country                       0
# Timezone                      7
# Airport_Code                  7
# Weather_Timestamp          1054
# Temperature(F)             1591
# Wind_Chill(F)             95678
# Humidity(%)                1856
# Pressure(in)               1292
# Visibility(mi)             1846
# Wind_Direction             1064
# Wind_Speed(mph)           23820
# Precipitation(in)         92632
# Weather_Condition          1604
# Amenity                       0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# Junction                      0
# No_Exit                       0
# Railway                       0
# Roundabout                    0
# Station                       0
# Stop                          0
# Traffic_Calming               0
# Traffic_Signal                0
# Turning_Loop                  0
# Sunrise_Sunset                1
# Civil_Twilight                1
# Nautical_Twilight             1
# Astronomical_Twilight         1
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# End_Lng                  100000
# End_Lat                  100000
# Wind_Chill(F)             95678
# Precipitation(in)         92632
# Wind_Speed(mph)           23820
# Humidity(%)                1856
# Visibility(mi)             1846
# Weather_Condition          1604
# Temperature(F)             1591
# Pressure(in)               1292
# Wind_Direction             1064
# Weather_Timestamp          1054
# Timezone                      7
# Zipcode                       7
# Airport_Code                  7
# Nautical_Twilight             1
# Civil_Twilight                1
# City                          1
# Astronomical_Twilight         1
# Sunrise_Sunset                1
# Description                   0
# Street                        0
# Source                        0
# ID                            0
# Severity                      0
# Distance(mi)                  0
# Start_Lng                     0
# Start_Time                    0
# End_Time                      0
# Start_Lat                     0
# County                        0
# Amenity                       0
# Country                       0
# State                         0
# Bump                          0
# Crossing                      0
# Give_Way                      0
# Junction                      0
# Station                       0
# Roundabout                    0
# Railway                       0
# No_Exit                       0
# Turning_Loop                  0
# Traffic_Signal                0
# Traffic_Calming               0
# Stop                          0
# dtype: int64

# %%
df = df.dropna(subset=['Start_Lat', 'Start_Lng'])

# %%
df['Start_Time'] = pd.to_datetime(df['Start_Time'])
df['End_Time'] = pd.to_datetime(df['End_Time'])

# %%
df['Hour'] = df['Start_Time'].dt.hour

# %%
df['Day'] = df['Start_Time'].dt.day_name()

# %%
df['Severity'].value_counts()
# Out:
# Severity
# 2    55025
# 3    44844
# 1       98
# 4       33
# Name: count, dtype: int64

# %%
sns.countplot(x='Severity', data=df)
plt.title("Accident Severity Distribution")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Hour', data=df)
plt.title("Accidents by Hour of Day")
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='Day', data=df,
              order=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'])
plt.xticks(rotation=45)
plt.title("Accidents by Day")
plt.show()

# %%
df['Traffic_Signal'].value_counts()
# Out:
# Traffic_Signal
# False    89301
# True     10699
# Name: count, dtype: int64

# %%
sns.countplot(x='Severity', hue='Traffic_Signal', data=df)
plt.title("Severity vs Traffic Signal")
plt.show()

# %%
m = folium.Map(location=[df['Start_Lat'].mean(),
                          df['Start_Lng'].mean()],
               zoom_start=5)

# %%
sample_df = df.sample(2000, random_state=42)

for _, row in sample_df.iterrows():
    folium.CircleMarker(
        location=[row['Start_Lat'], row['Start_Lng']],
        radius=3,
        color='red',
        fill=True,
        fill_opacity=0.6
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a9c7e3d9adf76033ad5ba02f64ab098 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a9c7e3d9adf76033ad5ba02f64ab098&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a9c7e3d9adf76033ad5ba02f64ab098 = L.map(
#                 &quot;map_9a9c7e3d9adf76033ad5ba02f64ab098&quot;,
#                 {
#                     center: [35.630368814920004, -119.32275633651],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b6dc7b51344cd2802f47da4ab9c92319 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b6dc7b51344cd2802f47da4ab9c92319.addTo(map_9a9c7e3d9adf76033ad5ba02f64ab098);
#
#
#             var circle_marker_031fab8c9563ad44fa2c8335e7783c0b = L.circleMarker(
#                 [34.027828, -118.2117],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a9c7e3d9adf76033ad5ba02f64ab098);
#
#
#             var circle_marker_67c0d6f6bc57410e4600e1504d092d9e = L.circleMarker(
#                 [33.93779, -117.556152],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a9c7e3d9adf76033ad5ba02f64ab098);
#
#
#             var circle_marker_f255b9e0555d79b73c6b8fae1c4b61c7 = L.circleMarker(
#                 [38.5536, -121.690643],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a9c7e3d9adf76033ad5ba02f64ab098);
#
#
#             var circle_marker_abe304a8cf2063a3f66bb4c0e2517723 = L.circleMarker(
#                 [33.965294, -117.326668],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a9c7e3d9adf76033ad5ba02f64ab098);
#
#
#             var circle_marker_c405290d92db5debdc059465dcaf2aba = L.circleMarker(
#                 [33.872710999999995, -118.284805],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9a9c7e3d9adf76033ad5ba02f64ab098);
#
#
#             var circle_marker_8cc7a7529574f864fda1c7d8ae6fd3fd = L.circleMarker(
#                 [34.022034000000005, -117.990417],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.6, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot
